# %%
import matplotlib as plt
import pandas as pd
from matplotlib import pyplot

data = pd.read_csv('/home/ikira/Desktop/agro_project/pshenica_quotes.csv', sep=';', parse_dates=['updated'])
data.updated

series = data[['updated', 'average']]
series.head()
series.set_index('updated', inplace = True)
# set
# series.
series.plot(figsize = (15,10))
# pyplot.show()
